# %% [markdown]
# ## CapstoneProject - Best Restaurant to work in Fortaleza-Brazil

# %% [markdown]
# ## Introduction/description of the problem
#
# -Kalil is a Master student in Technical Logistics in Germany. After the corona crisis, the brazilian currency had a strong fluctutiation and Kalil has to go back to his parents house due to the financial crisis.
#
# -However, Kalil did not finished his master and he must work to survive. He has professional skills in the cuisine and he had the idea to work in restaurants for a short period until the situation become better and he goes back to Germany and finish his master.
#
# -The question is, in which restaurant should he look for a work? The core of the problem is that Kalil does not have money. In order to saving money, kalil muss avoid spend money with transportation and oder expenses. Then, he needs to work nearby and in a good restaurant with the idea to get bigger tips (Mostly the tips are an obligation in Brazil and normally is included in the payment).
#
# Premisses are:
#
# - Restaurants nearby
# - Restaurants with good reputation
# - Restaurants can be accessed by foot (without bus, car, bike)
# - Kalil does not remember the locations in Fortaleza, so he needs the locations plot in a Map for orientation

# %% [markdown]
# ## Data
#
# Data description: the data used to solve this problem is geocode, and it is obtained from FourSquare. Explanation and  the steps, with examples, of the data is the following. Data is a single dataframe containing locations nearby the parent's house of Kalil. Primarly data is based on the lat,lng and radius(2km). Some other metadata like name, categories, area, post code, distances and so on is also collected, but let us discuss that some of them are not  necessary for the analysis.

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.9.2         |   py36h45558ae_0         613 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.4               |   py36h830a2c2_0        10.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.9.2-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.4-py36h830a2c2_0
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# pandas-1.0.4         | 10.1 MB   | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# cryptography-2.9.2   | 613 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = 'EZTP0DUNMD3TKQDJDOQFXN3ORJU4FCB5W4RG4DLMVDCGRGFT' # your Foursquare ID
CLIENT_SECRET = 'E12WSECYOLAAVMEKS0KSMWJYG4XUQMFZJQ305DCV4N1VLW1E' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EZTP0DUNMD3TKQDJDOQFXN3ORJU4FCB5W4RG4DLMVDCGRGFT
# CLIENT_SECRET:E12WSECYOLAAVMEKS0KSMWJYG4XUQMFZJQ305DCV4N1VLW1E

# %% [markdown]
# #### Let's again assume that you are staying at the Conrad hotel. So let's start by converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = 'Rua Jornalista Cesar Magalhães, 666'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -3.7633031 -38.4910458

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### So, let's define a query to search for Restaurant that is within 2000 metres from the parent's house

# %%
search_query = 'restaurant'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=EZTP0DUNMD3TKQDJDOQFXN3ORJU4FCB5W4RG4DLMVDCGRGFT&client_secret=E12WSECYOLAAVMEKS0KSMWJYG4XUQMFZJQ305DCV4N1VLW1E&ll=-3.7633031,-38.4910458&v=20180604&query=restaurant&radius=2000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ed91bbc963d29001b63e5e3'},
#  'response': {'venues': [{'id': '4e9d9eb72c5b8638e57d7daa',
#     'name': 'Restaurante Dona Malu',
#     'location': {'lat': -3.7594491890431607,
#      'lng': -38.487703193511834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7594491890431607,
#        'lng': -38.487703193511834}],
#      'distance': 567,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4cfe445b2c1aa0907422067a',
#     'name': 'Restaurante Alecrim Verde',
#     'location': {'address': 'Rua henriqueta galeno 920',
#      'lat': -3.7479258834779627,
#      'lng': -38.49174431913736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7479258834779627,
#        'lng': -38.49174431913736}],
#      'distance': 1713,
#      'postalCode': '60135-420',
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua henriqueta galeno 920',
#       'Fortaleza, CE',
#       '60135-420',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '563ccfeecd10bfc081e30a20',
#     'name': 'Restaurante Da Fa7',
#     'location': {'lat': -3.766255879406433,
#      'lng': -38.4943828993284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.766255879406433,
#        'lng': -38.4943828993284}],
#      'distance': 495,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a00',
#       'name': 'Comfort Food Restaurant',
#       'pluralName': 'Comfort Food Restaurants',
#       'shortName': 'Comfort Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '52791a8b498e214e9f44f815',
#     'name': 'restaurante 4 rodas',
#     'location': {'lat': -3.75884747505188,
#      'lng': -38.4873046875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.75884747505188,
#        'lng': -38.4873046875}],
#      'distance': 647,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '50358c52e4b0cf42407560f7',
#     'name': 'restaurante churrascaria serrana',
#     'location': {'lat': -3.764546196986964,
#      'lng': -38.496025284214525,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.764546196986964,
#        'lng': -38.496025284214525}],
#      'distance': 570,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '5183e155498e448ef51b3f99',
#     'name': 'Restaurante e marmitaria salve Jorge, Rua cmt José de Oliveira, 170',
#     'location': {'lat': -3.7583597,
#      'lng': -38.489662,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7583597,
#        'lng': -38.489662}],
#      'distance': 571,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4de66c6fd1648041649f33b1',
#     'name': 'Restaurante Recanto dos Amigos',
#     'location': {'address': 'Rua Leonardo Mota, 2486',
#      'lat': -3.7473003060229173,
#      'lng': -38.49979729225605,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7473003060229173,
#        'lng': -38.49979729225605}],
#      'distance': 2029,
#      'postalCode': '60170-041',
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Leonardo Mota, 2486',
#       'Fortaleza, CE',
#       '60170-041',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '572cf0de498ea4b92e314c1c',
#     'name': 'Restaurante Tomate Cereja',
#     'location': {'address': 'Rua Luiza Miranda Coelho 1555',
#      'lat': -3.7761877192548865,
#      'lng': -38.482428186827136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7761877192548865,
#        'lng': -38.482428186827136}],
#      'distance': 1724,
#      'postalCode': '60811-110',
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Luiza Miranda Coelho 1555',
#       'Fortaleza, CE',
#       '60811-110',
#       'Brasil']},
#     'categories': [{'id': '52e81612bcbc57f1066b79f4',
#       'name': 'Buffet',
#       'pluralName': 'Buffets',
#       'shortName': 'Buffet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '50e5a4ece4b06f58a73ba41f',
#     'name': 'Restaurante Republica',
#     'location': {'lat': -3.7678875947065262,
#      'lng': -38.49465492214674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7678875947065262,
#        'lng': -38.49465492214674}],
#      'distance': 648,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4fa93f5ee4b007be2cc77ed2',
#     'name': 'Restaurante do Forum',
#     'location': {'address': 'R. Desembargador Floriano Benevides, 220',
#      'lat': -3.773600866484024,
#      'lng': -38.47819400665982,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.773600866484024,
#        'lng': -38.47819400665982}],
#      'distance': 1830,
#      'postalCode': '60811-690',
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Desembargador Floriano Benevides, 220',
#       'Fortaleza, CE',
#       '60811-690',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4fa81bd1e4b0548308cd893d',
#     'name': 'Restaurante Nutrição - fórum',
#     'location': {'lat': -3.773596987400553,
#      'lng': -38.480159165174406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.773596987400553,
#        'lng': -38.480159165174406}],
#      'distance': 1665,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '54ff0de2498e1fc1414700f7',
#     'name': 'Restaurante Delícias de Maria',
#     'location': {'address': 'Rua Osvaldo Cruz',
#      'lat': -3.7464735714565167,
#      'lng': -38.50371907668569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7464735714565167,
#        'lng': -38.50371907668569}],
#      'distance': 2343,
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Osvaldo Cruz', 'Fortaleza, CE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4ced2eded7268cfacaa5c14e',
#     'name': 'Restaurante Oriental',
#     'location': {'address': 'Rua Desembargador Faustino de Albuquerque, 290',
#      'lat': -3.7820335278683013,
#      'lng': -38.49850814066202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7820335278683013,
#        'lng': -38.49850814066202}],
#      'distance': 2243,
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Desembargador Faustino de Albuquerque, 290',
#       'Fortaleza, CE',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '55bf5a5b498e34359819b58e',
#     'name': 'Restaurante Fórum',
#     'location': {'lat': -3.773351943291931,
#      'lng': -38.47995788411251,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.773351943291931,
#        'lng': -38.47995788411251}],
#      'distance': 1663,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4e94e6566d8689834d758cf8',
#     'name': 'Restaurante e Lanchonete Petit Bom',
#     'location': {'address': 'Faculdade 7 de Setembro',
#      'lat': -3.7714420474552592,
#      'lng': -38.4826397895813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7714420474552592,
#        'lng': -38.4826397895813}],
#      'distance': 1301,
#      'postalCode': '60811-020',
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Faculdade 7 de Setembro',
#       'Fortaleza, CE',
#       '60811-020',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '53a42a06498ea4bed5a9ac26',
#     'name': 'Restaurante Recanto',
#     'location': {'lat': -3.7697540060663117,
#      'lng': -38.484265934667526,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7697540060663117,
#        'lng': -38.484265934667526}],
#      'distance': 1040,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4f846840e4b07ae14168a76d',
#     'name': 'Restaurante Big Food',
#     'location': {'address': 'Rua Joaquim Sá',
#      'lat': -3.750721452126703,
#      'lng': -38.50148592032196,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.750721452126703,
#        'lng': -38.50148592032196}],
#      'distance': 1818,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Joaquim Sá', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '505c72b0e4b05434c060f07b',
#     'name': 'Restaurante Delícias caseira',
#     'location': {'lat': -3.772254082554346,
#      'lng': -38.482227982193514,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.772254082554346,
#        'lng': -38.482227982193514}],
#      'distance': 1397,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '55439f30498ef2b968962fb9',
#     'name': 'Restaurante Comida de Casa',
#     'location': {'lat': -3.7715936634351497,
#      'lng': -38.482274183323426,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7715936634351497,
#        'lng': -38.482274183323426}],
#      'distance': 1342,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '545b9151498eac0b6597fe40',
#     'name': 'Restaurante Da D. Nádia',
#     'location': {'address': 'Rua Hill Morais',
#      'lat': -3.7751132780576393,
#      'lng': -38.47740235306526,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7751132780576393,
#        'lng': -38.47740235306526}],
#      'distance': 2006,
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Hill Morais', 'Fortaleza, CE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4ffc446ee4b09736bd11d339',
#     'name': 'Restaurante estrela',
#     'location': {'lat': -3.7713639938588157,
#      'lng': -38.482412786519426,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7713639938588157,
#        'lng': -38.482412786519426}],
#      'distance': 1313,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '509eea6ae4b01718b2ee95a1',
#     'name': 'Restaurante Barcelona',
#     'location': {'address': 'Centro De E Eventos',
#      'lat': -3.754247166992886,
#      'lng': -38.48371153568143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.754247166992886,
#        'lng': -38.48371153568143}],
#      'distance': 1296,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Centro De E Eventos', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4ed3aee18b81b4739a5777ea',
#     'name': 'Restaurante Boca De Caititu',
#     'location': {'lat': -3.747319548105741,
#      'lng': -38.498848037825084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.747319548105741,
#        'lng': -38.498848037825084}],
#      'distance': 1979,
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Fortaleza, CE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4eebea008b81bbbf5b6093d0',
#     'name': 'Restaurante Robertus',
#     'location': {'address': 'Rua Marcondes Pereira, 1414',
#      'lat': -3.750328,
#      'lng': -38.504158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.750328,
#        'lng': -38.504158}],
#      'distance': 2051,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Marcondes Pereira, 1414', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '506b105de4b0670d3fe3e137',
#     'name': 'Restaurante da christus',
#     'location': {'address': 'Adolfo Gurgel,133',
#      'lat': -3.7479151284509076,
#      'lng': -38.481119145389634,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7479151284509076,
#        'lng': -38.481119145389634}],
#      'distance': 2037,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Adolfo Gurgel,133', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '5a1f2f04c0f1634ab4e85b48',
#     'name': 'Restaurante Grego',
#     'location': {'lat': -3.751266,
#      'lng': -38.495982,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.751266,
#        'lng': -38.495982}],
#      'distance': 1447,
#      'postalCode': '60192-765',
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Fortaleza, CE', '60192-765', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '543e7e63498e6f51e7216fc4',
#     'name': 'Restaurante Pipo',
#     'location': {'address': 'Rua Israel Bezerra',
#      'lat': -3.751415552954718,
#      'lng': -38.49348335704751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.751415552954718,
#        'lng': -38.49348335704751}],
#      'distance': 1350,
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Israel Bezerra', 'Fortaleza, CE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '4f5f5bf6e4b040463da3637b',
#     'name': 'Restaurante Adega - Colégio Santo Inácio',
#     'location': {'lat': -3.7464590072631836,
#      'lng': -38.50132369995117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.7464590072631836,
#        'lng': -38.50132369995117}],
#      'distance': 2195,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '506b0cfde4b0b2645d2250d8',
#     'name': 'Restaurante da Susuh',
#     'location': {'lat': -3.751556625217167,
#      'lng': -38.50350275161047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.751556625217167,
#        'lng': -38.50350275161047}],
#      'distance': 1903,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False},
#    {'id': '5555490b498ecb1f1108e821',
#     'name': 'Restaurante Terra Do Sol',
#     'location': {'address': 'Luciano Cavalcante',
#      'lat': -3.776910591665272,
#      'lng': -38.49682593204027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -3.776910591665272,
#        'lng': -38.49682593204027}],
#      'distance': 1645,
#      'cc': 'BR',
#      'city': 'Fortaleza',
#      'state': 'CE',
#      'country': 'Brasil',
#      'formattedAddress': ['Luciano Cavalcante', 'Fortaleza, CE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591287151',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                              name  \
# 0  4e9d9eb72c5b8638e57d7daa  Restaurante Dona Malu
# 1  4cfe445b2c1aa0907422067a  Restaurante Alecrim Verde
# 2  563ccfeecd10bfc081e30a20  Restaurante Da Fa7
# 3  52791a8b498e214e9f44f815  restaurante 4 rodas
# 4  50358c52e4b0cf42407560f7  restaurante churrascaria serrana
#
#                                                                                                                                                                                                                                                       categories  \
# 0  [{'id': '4bf58dd8d48988d16b941735', 'name': 'Brazilian Restaurant', 'pluralName': 'Brazilian Restaurants', 'shortName': 'Brazilian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '4bf58dd8d48988d16b941735', 'name': 'Brazilian Restaurant', 'pluralName': 'Brazilian Restaurants', 'shortName': 'Brazilian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '52e81612bcbc57f1066b7a00', 'name': 'Comfort Food Restaurant', 'pluralName': 'Comfort Food Restaurants', 'shortName': 'Comfort Food', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'Restaurant', 'pluralName': 'Restaurants', 'shortName': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# 4  [{'id': '4bf58dd8d48988d1df931735', 'name': 'BBQ Joint', 'pluralName': 'BBQ Joints', 'shortName': 'BBQ', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_', 'suffix': '.png'}, 'primary': True}]
#
#      referralId  hasPerk  location.lat  location.lng  \
# 0  v-1591287151  False   -3.759449     -38.487703
# 1  v-1591287151  False   -3.747926     -38.491744
# 2  v-1591287151  False   -3.766256     -38.494383
# 3  v-1591287151  False   -3.758847     -38.487305
# 4  v-1591287151  False   -3.764546     -38.496025
#
#                                                           location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': -3.7594491890431607, 'lng': -38.487703193511834}]
# 1  [{'label': 'display', 'lat': -3.7479258834779627, 'lng': -38.49174431913736}]
# 2  [{'label': 'display', 'lat': -3.766255879406433, 'lng': -38.4943828993284}]
# 3  [{'label': 'display', 'lat': -3.75884747505188, 'lng': -38.4873046875}]
# 4  [{'label': 'display', 'lat': -3.764546196986964, 'lng': -38.496025284214525}]
#
#    location.distance location.cc location.country  \
# 0  567                BR          Brasil
# 1  1713               BR          Brasil
# 2  495                BR          Brasil
# 3  647                BR          Brasil
# 4  570                BR          Brasil
#
#                                        location.formattedAddress  \
# 0  [Brasil]
# 1  [Rua henriqueta galeno 920, Fortaleza, CE, 60135-420, Brasil]
# 2  [Brasil]
# 3  [Brasil]
# 4  [Brasil]
#
#             location.address location.postalCode location.city location.state
# 0  NaN                        NaN                 NaN           NaN
# 1  Rua henriqueta galeno 920  60135-420           Fortaleza     CE
# 2  NaN                        NaN                 NaN           NaN
# 3  NaN                        NaN                 NaN           NaN
# 4  NaN                        NaN                 NaN           NaN

# %%
dataframe.shape
# Out:
# (30, 16)

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                                    name  \
# 0   Restaurante Dona Malu
# 1   Restaurante Alecrim Verde
# 2   Restaurante Da Fa7
# 3   restaurante 4 rodas
# 4   restaurante churrascaria serrana
# 5   Restaurante e marmitaria salve Jorge, Rua cmt José de Oliveira, 170
# 6   Restaurante Recanto dos Amigos
# 7   Restaurante Tomate Cereja
# 8   Restaurante Republica
# 9   Restaurante do Forum
# 10  Restaurante Nutrição - fórum
# 11  Restaurante Delícias de Maria
# 12  Restaurante Oriental
# 13  Restaurante Fórum
# 14  Restaurante e Lanchonete Petit Bom
# 15  Restaurante Recanto
# 16  Restaurante Big Food
# 17  Restaurante Delícias caseira
# 18  Restaurante Comida de Casa
# 19  Restaurante Da D. Nádia
# 20  Restaurante estrela
# 21  Restaurante Barcelona
# 22  Restaurante Boca De Caititu
# 23  Restaurante Robertus
# 24  Restaurante da christus
# 25  Restaurante Grego
# 26  Restaurante Pipo
# 27  Restaurante Adega - Colégio Santo Inácio
# 28  Restaurante da Susuh
# 29  Restaurante Terra Do Sol
#
#                  categories       lat        lng  \
# 0   Brazilian Restaurant    -3.759449 -38.487703
# 1   Brazilian Restaurant    -3.747926 -38.491744
# 2   Comfort Food Restaurant -3.766256 -38.494383
# 3   Restaurant              -3.758847 -38.487305
# 4   BBQ Joint               -3.764546 -38.496025
# 5   Brazilian Restaurant    -3.758360 -38.489662
# 6   Restaurant              -3.747300 -38.499797
# 7   Buffet                  -3.776188 -38.482428
# 8   BBQ Joint               -3.767888 -38.494655
# 9   Cafeteria               -3.773601 -38.478194
# 10  Brazilian Restaurant    -3.773597 -38.480159
# 11  Restaurant              -3.746474 -38.503719
# 12  Chinese Restaurant      -3.782034 -38.498508
# 13  Restaurant              -3.773352 -38.479958
# 14  Brazilian Restaurant    -3.771442 -38.482640
# 15  Restaurant              -3.769754 -38.484266
# 16  Brazilian Restaurant    -3.750721 -38.501486
# 17  Brazilian Restaurant    -3.772254 -38.482228
# 18  Restaurant              -3.771594 -38.482274
# 19  Brazilian Restaurant    -3.775113 -38.477402
# 20  Diner                   -3.771364 -38.482413
# 21  Brazilian Restaurant    -3.754247 -38.483712
# 22  Brazilian Restaurant    -3.747320 -38.498848
# 23  Restaurant              -3.750328 -38.504158
# 24  Brazilian Restaurant    -3.747915 -38.481119
# 25  Greek Restaurant        -3.751266 -38.495982
# 26  Italian Restaurant      -3.751416 -38.493483
# 27  Restaurant              -3.746459 -38.501324
# 28  Food Truck              -3.751557 -38.503503
# 29  Brazilian Restaurant    -3.776911 -38.496826
#
#                                                                     labeledLatLngs  \
# 0   [{'label': 'display', 'lat': -3.7594491890431607, 'lng': -38.487703193511834}]
# 1   [{'label': 'display', 'lat': -3.7479258834779627, 'lng': -38.49174431913736}]
# 2   [{'label': 'display', 'lat': -3.766255879406433, 'lng': -38.4943828993284}]
# 3   [{'label': 'display', 'lat': -3.75884747505188, 'lng': -38.4873046875}]
# 4   [{'label': 'display', 'lat': -3.764546196986964, 'lng': -38.496025284214525}]
# 5   [{'label': 'display', 'lat': -3.7583597, 'lng': -38.489662}]
# 6   [{'label': 'display', 'lat': -3.7473003060229173, 'lng': -38.49979729225605}]
# 7   [{'label': 'display', 'lat': -3.7761877192548865, 'lng': -38.482428186827136}]
# 8   [{'label': 'display', 'lat': -3.7678875947065262, 'lng': -38.49465492214674}]
# 9   [{'label': 'display', 'lat': -3.773600866484024, 'lng': -38.47819400665982}]
# 10  [{'label': 'display', 'lat': -3.773596987400553, 'lng': -38.480159165174406}]
# 11  [{'label': 'display', 'lat': -3.7464735714565167, 'lng': -38.50371907668569}]
# 12  [{'label': 'display', 'lat': -3.7820335278683013, 'lng': -38.49850814066202}]
# 13  [{'label': 'display', 'lat': -3.773351943291931, 'lng': -38.47995788411251}]
# 14  [{'label': 'display', 'lat': -3.7714420474552592, 'lng': -38.4826397895813}]
# 15  [{'label': 'display', 'lat': -3.7697540060663117, 'lng': -38.484265934667526}]
# 16  [{'label': 'display', 'lat': -3.750721452126703, 'lng': -38.50148592032196}]
# 17  [{'label': 'display', 'lat': -3.772254082554346, 'lng': -38.482227982193514}]
# 18  [{'label': 'display', 'lat': -3.7715936634351497, 'lng': -38.482274183323426}]
# 19  [{'label': 'display', 'lat': -3.7751132780576393, 'lng': -38.47740235306526}]
# 20  [{'label': 'display', 'lat': -3.7713639938588157, 'lng': -38.482412786519426}]
# 21  [{'label': 'display', 'lat': -3.754247166992886, 'lng': -38.48371153568143}]
# 22  [{'label': 'display', 'lat': -3.747319548105741, 'lng': -38.498848037825084}]
# 23  [{'label': 'display', 'lat': -3.750328, 'lng': -38.504158}]
# 24  [{'label': 'display', 'lat': -3.7479151284509076, 'lng': -38.481119145389634}]
# 25  [{'label': 'display', 'lat': -3.751266, 'lng': -38.495982}]
# 26  [{'label': 'display', 'lat': -3.751415552954718, 'lng': -38.49348335704751}]
# 27  [{'label': 'display', 'lat': -3.7464590072631836, 'lng': -38.50132369995117}]
# 28  [{'label': 'display', 'lat': -3.751556625217167, 'lng': -38.50350275161047}]
# 29  [{'label': 'display', 'lat': -3.776910591665272, 'lng': -38.49682593204027}]
#
#     distance  cc country  \
# 0   567       BR  Brasil
# 1   1713      BR  Brasil
# 2   495       BR  Brasil
# 3   647       BR  Brasil
# 4   570       BR  Brasil
# 5   571       BR  Brasil
# 6   2029      BR  Brasil
# 7   1724      BR  Brasil
# 8   648       BR  Brasil
# 9   1830      BR  Brasil
# 10  1665      BR  Brasil
# 11  2343      BR  Brasil
# 12  2243      BR  Brasil
# 13  1663      BR  Brasil
# 14  1301      BR  Brasil
# 15  1040      BR  Brasil
# 16  1818      BR  Brasil
# 17  1397      BR  Brasil
# 18  1342      BR  Brasil
# 19  2006      BR  Brasil
# 20  1313      BR  Brasil
# 21  1296      BR  Brasil
# 22  1979      BR  Brasil
# 23  2051      BR  Brasil
# 24  2037      BR  Brasil
# 25  1447      BR  Brasil
# 26  1350      BR  Brasil
# 27  2195      BR  Brasil
# 28  1903      BR  Brasil
# 29  1645      BR  Brasil
#
#                                                                 formattedAddress  \
# 0   [Brasil]
# 1   [Rua henriqueta galeno 920, Fortaleza, CE, 60135-420, Brasil]
# 2   [Brasil]
# 3   [Brasil]
# 4   [Brasil]
# 5   [Brasil]
# 6   [Rua Leonardo Mota, 2486, Fortaleza, CE, 60170-041, Brasil]
# 7   [Rua Luiza Miranda Coelho 1555, Fortaleza, CE, 60811-110, Brasil]
# 8   [Brasil]
# 9   [R. Desembargador Floriano Benevides, 220, Fortaleza, CE, 60811-690, Brasil]
# 10  [Brasil]
# 11  [Rua Osvaldo Cruz, Fortaleza, CE, Brasil]
# 12  [Rua Desembargador Faustino de Albuquerque, 290, Fortaleza, CE, Brasil]
# 13  [Brasil]
# 14  [Faculdade 7 de Setembro, Fortaleza, CE, 60811-020, Brasil]
# 15  [Brasil]
# 16  [Rua Joaquim Sá, Brasil]
# 17  [Brasil]
# 18  [Brasil]
# 19  [Rua Hill Morais, Fortaleza, CE, Brasil]
# 20  [Brasil]
# 21  [Centro De E Eventos, Brasil]
# 22  [Fortaleza, CE, Brasil]
# 23  [Rua Marcondes Pereira, 1414, Brasil]
# 24  [Adolfo Gurgel,133, Brasil]
# 25  [Fortaleza, CE, 60192-765, Brasil]
# 26  [Rua Israel Bezerra, Fortaleza, CE, Brasil]
# 27  [Brasil]
# 28  [Brasil]
# 29  [Luciano Cavalcante, Fortaleza, CE, Brasil]
#
#                                            address postalCode       city  \
# 0   NaN                                             NaN        NaN
# 1   Rua henriqueta galeno 920                       60135-420  Fortaleza
# 2   NaN                                             NaN        NaN
# 3   NaN                                             NaN        NaN
# 4   NaN                                             NaN        NaN
# 5   NaN                                             NaN        NaN
# 6   Rua Leonardo Mota, 2486                         60170-041  Fortaleza
# 7   Rua Luiza Miranda Coelho 1555                   60811-110  Fortaleza
# 8   NaN                                             NaN        NaN
# 9   R. Desembargador Floriano Benevides, 220        60811-690  Fortaleza
# 10  NaN                                             NaN        NaN
# 11  Rua Osvaldo Cruz                                NaN        Fortaleza
# 12  Rua Desembargador Faustino de Albuquerque, 290  NaN        Fortaleza
# 13  NaN                                             NaN        NaN
# 14  Faculdade 7 de Setembro                         60811-020  Fortaleza
# 15  NaN                                             NaN        NaN
# 16  Rua Joaquim Sá                                  NaN        NaN
# 17  NaN                                             NaN        NaN
# 18  NaN                                             NaN        NaN
# 19  Rua Hill Morais                                 NaN        Fortaleza
# 20  NaN                                             NaN        NaN
# 21  Centro De E Eventos                             NaN        NaN
# 22  NaN                                             NaN        Fortaleza
# 23  Rua Marcondes Pereira, 1414                     NaN        NaN
# 24  Adolfo Gurgel,133                               NaN        NaN
# 25  NaN                                             60192-765  Fortaleza
# 26  Rua Israel Bezerra                              NaN        Fortaleza
# 27  NaN                                             NaN        NaN
# 28  NaN                                             NaN        NaN
# 29  Luciano Cavalcante                              NaN        Fortaleza
#
#    state                        id
# 0   NaN   4e9d9eb72c5b8638e57d7daa
# 1   CE    4cfe445b2c1aa0907422067a
# 2   NaN   563ccfeecd10bfc081e30a20
# 3   NaN   52791a8b498e214e9f44f815
# 4   NaN   50358c52e4b0cf42407560f7
# 5   NaN   5183e155498e448ef51b3f99
# 6   CE    4de66c6fd1648041649f33b1
# 7   CE    572cf0de498ea4b92e314c1c
# 8   NaN   50e5a4ece4b06f58a73ba41f
# 9   CE    4fa93f5ee4b007be2cc77ed2
# 10  NaN   4fa81bd1e4b0548308cd893d
# 11  CE    54ff0de2498e1fc1414700f7
# 12  CE    4ced2eded7268cfacaa5c14e
# 13  NaN   55bf5a5b498e34359819b58e
# 14  CE    4e94e6566d8689834d758cf8
# 15  NaN   53a42a06498ea4bed5a9ac26
# 16  NaN   4f846840e4b07ae14168a76d
# 17  NaN   505c72b0e4b05434c060f07b
# 18  NaN   55439f30498ef2b968962fb9
# 19  CE    545b9151498eac0b6597fe40
# 20  NaN   4ffc446ee4b09736bd11d339
# 21  NaN   509eea6ae4b01718b2ee95a1
# 22  CE    4ed3aee18b81b4739a5777ea
# 23  NaN   4eebea008b81bbbf5b6093d0
# 24  NaN   506b105de4b0670d3fe3e137
# 25  CE    5a1f2f04c0f1634ab4e85b48
# 26  CE    543e7e63498e6f51e7216fc4
# 27  NaN   4f5f5bf6e4b040463da3637b
# 28  NaN   506b0cfde4b0b2645d2250d8
# 29  CE    5555490b498ecb1f1108e821

# %%
fortaleza_df1 = dataframe_filtered.drop(['labeledLatLngs', 'formattedAddress','address','postalCode','city','state',], axis=1)
fortaleza_df1
# Out:
#                                                                    name  \
# 0   Restaurante Dona Malu
# 1   Restaurante Alecrim Verde
# 2   Restaurante Da Fa7
# 3   restaurante 4 rodas
# 4   restaurante churrascaria serrana
# 5   Restaurante e marmitaria salve Jorge, Rua cmt José de Oliveira, 170
# 6   Restaurante Recanto dos Amigos
# 7   Restaurante Tomate Cereja
# 8   Restaurante Republica
# 9   Restaurante do Forum
# 10  Restaurante Nutrição - fórum
# 11  Restaurante Delícias de Maria
# 12  Restaurante Oriental
# 13  Restaurante Fórum
# 14  Restaurante e Lanchonete Petit Bom
# 15  Restaurante Recanto
# 16  Restaurante Big Food
# 17  Restaurante Delícias caseira
# 18  Restaurante Comida de Casa
# 19  Restaurante Da D. Nádia
# 20  Restaurante estrela
# 21  Restaurante Barcelona
# 22  Restaurante Boca De Caititu
# 23  Restaurante Robertus
# 24  Restaurante da christus
# 25  Restaurante Grego
# 26  Restaurante Pipo
# 27  Restaurante Adega - Colégio Santo Inácio
# 28  Restaurante da Susuh
# 29  Restaurante Terra Do Sol
#
#                  categories       lat        lng  distance  cc country  \
# 0   Brazilian Restaurant    -3.759449 -38.487703  567       BR  Brasil
# 1   Brazilian Restaurant    -3.747926 -38.491744  1713      BR  Brasil
# 2   Comfort Food Restaurant -3.766256 -38.494383  495       BR  Brasil
# 3   Restaurant              -3.758847 -38.487305  647       BR  Brasil
# 4   BBQ Joint               -3.764546 -38.496025  570       BR  Brasil
# 5   Brazilian Restaurant    -3.758360 -38.489662  571       BR  Brasil
# 6   Restaurant              -3.747300 -38.499797  2029      BR  Brasil
# 7   Buffet                  -3.776188 -38.482428  1724      BR  Brasil
# 8   BBQ Joint               -3.767888 -38.494655  648       BR  Brasil
# 9   Cafeteria               -3.773601 -38.478194  1830      BR  Brasil
# 10  Brazilian Restaurant    -3.773597 -38.480159  1665      BR  Brasil
# 11  Restaurant              -3.746474 -38.503719  2343      BR  Brasil
# 12  Chinese Restaurant      -3.782034 -38.498508  2243      BR  Brasil
# 13  Restaurant              -3.773352 -38.479958  1663      BR  Brasil
# 14  Brazilian Restaurant    -3.771442 -38.482640  1301      BR  Brasil
# 15  Restaurant              -3.769754 -38.484266  1040      BR  Brasil
# 16  Brazilian Restaurant    -3.750721 -38.501486  1818      BR  Brasil
# 17  Brazilian Restaurant    -3.772254 -38.482228  1397      BR  Brasil
# 18  Restaurant              -3.771594 -38.482274  1342      BR  Brasil
# 19  Brazilian Restaurant    -3.775113 -38.477402  2006      BR  Brasil
# 20  Diner                   -3.771364 -38.482413  1313      BR  Brasil
# 21  Brazilian Restaurant    -3.754247 -38.483712  1296      BR  Brasil
# 22  Brazilian Restaurant    -3.747320 -38.498848  1979      BR  Brasil
# 23  Restaurant              -3.750328 -38.504158  2051      BR  Brasil
# 24  Brazilian Restaurant    -3.747915 -38.481119  2037      BR  Brasil
# 25  Greek Restaurant        -3.751266 -38.495982  1447      BR  Brasil
# 26  Italian Restaurant      -3.751416 -38.493483  1350      BR  Brasil
# 27  Restaurant              -3.746459 -38.501324  2195      BR  Brasil
# 28  Food Truck              -3.751557 -38.503503  1903      BR  Brasil
# 29  Brazilian Restaurant    -3.776911 -38.496826  1645      BR  Brasil
#
#                           id
# 0   4e9d9eb72c5b8638e57d7daa
# 1   4cfe445b2c1aa0907422067a
# 2   563ccfeecd10bfc081e30a20
# 3   52791a8b498e214e9f44f815
# 4   50358c52e4b0cf42407560f7
# 5   5183e155498e448ef51b3f99
# 6   4de66c6fd1648041649f33b1
# 7   572cf0de498ea4b92e314c1c
# 8   50e5a4ece4b06f58a73ba41f
# 9   4fa93f5ee4b007be2cc77ed2
# 10  4fa81bd1e4b0548308cd893d
# 11  54ff0de2498e1fc1414700f7
# 12  4ced2eded7268cfacaa5c14e
# 13  55bf5a5b498e34359819b58e
# 14  4e94e6566d8689834d758cf8
# 15  53a42a06498ea4bed5a9ac26
# 16  4f846840e4b07ae14168a76d
# 17  505c72b0e4b05434c060f07b
# 18  55439f30498ef2b968962fb9
# 19  545b9151498eac0b6597fe40
# 20  4ffc446ee4b09736bd11d339
# 21  509eea6ae4b01718b2ee95a1
# 22  4ed3aee18b81b4739a5777ea
# 23  4eebea008b81bbbf5b6093d0
# 24  506b105de4b0670d3fe3e137
# 25  5a1f2f04c0f1634ab4e85b48
# 26  543e7e63498e6f51e7216fc4
# 27  4f5f5bf6e4b040463da3637b
# 28  506b0cfde4b0b2645d2250d8
# 29  5555490b498ecb1f1108e821

# %%
fortaleza_df= fortaleza_df1.sort_values(by=['distance'])
fortaleza_df
# Out:
#                                                                    name  \
# 2   Restaurante Da Fa7
# 0   Restaurante Dona Malu
# 4   restaurante churrascaria serrana
# 5   Restaurante e marmitaria salve Jorge, Rua cmt José de Oliveira, 170
# 3   restaurante 4 rodas
# 8   Restaurante Republica
# 15  Restaurante Recanto
# 21  Restaurante Barcelona
# 14  Restaurante e Lanchonete Petit Bom
# 20  Restaurante estrela
# 18  Restaurante Comida de Casa
# 26  Restaurante Pipo
# 17  Restaurante Delícias caseira
# 25  Restaurante Grego
# 29  Restaurante Terra Do Sol
# 13  Restaurante Fórum
# 10  Restaurante Nutrição - fórum
# 1   Restaurante Alecrim Verde
# 7   Restaurante Tomate Cereja
# 16  Restaurante Big Food
# 9   Restaurante do Forum
# 28  Restaurante da Susuh
# 22  Restaurante Boca De Caititu
# 19  Restaurante Da D. Nádia
# 6   Restaurante Recanto dos Amigos
# 24  Restaurante da christus
# 23  Restaurante Robertus
# 27  Restaurante Adega - Colégio Santo Inácio
# 12  Restaurante Oriental
# 11  Restaurante Delícias de Maria
#
#                  categories       lat        lng  distance  cc country  \
# 2   Comfort Food Restaurant -3.766256 -38.494383  495       BR  Brasil
# 0   Brazilian Restaurant    -3.759449 -38.487703  567       BR  Brasil
# 4   BBQ Joint               -3.764546 -38.496025  570       BR  Brasil
# 5   Brazilian Restaurant    -3.758360 -38.489662  571       BR  Brasil
# 3   Restaurant              -3.758847 -38.487305  647       BR  Brasil
# 8   BBQ Joint               -3.767888 -38.494655  648       BR  Brasil
# 15  Restaurant              -3.769754 -38.484266  1040      BR  Brasil
# 21  Brazilian Restaurant    -3.754247 -38.483712  1296      BR  Brasil
# 14  Brazilian Restaurant    -3.771442 -38.482640  1301      BR  Brasil
# 20  Diner                   -3.771364 -38.482413  1313      BR  Brasil
# 18  Restaurant              -3.771594 -38.482274  1342      BR  Brasil
# 26  Italian Restaurant      -3.751416 -38.493483  1350      BR  Brasil
# 17  Brazilian Restaurant    -3.772254 -38.482228  1397      BR  Brasil
# 25  Greek Restaurant        -3.751266 -38.495982  1447      BR  Brasil
# 29  Brazilian Restaurant    -3.776911 -38.496826  1645      BR  Brasil
# 13  Restaurant              -3.773352 -38.479958  1663      BR  Brasil
# 10  Brazilian Restaurant    -3.773597 -38.480159  1665      BR  Brasil
# 1   Brazilian Restaurant    -3.747926 -38.491744  1713      BR  Brasil
# 7   Buffet                  -3.776188 -38.482428  1724      BR  Brasil
# 16  Brazilian Restaurant    -3.750721 -38.501486  1818      BR  Brasil
# 9   Cafeteria               -3.773601 -38.478194  1830      BR  Brasil
# 28  Food Truck              -3.751557 -38.503503  1903      BR  Brasil
# 22  Brazilian Restaurant    -3.747320 -38.498848  1979      BR  Brasil
# 19  Brazilian Restaurant    -3.775113 -38.477402  2006      BR  Brasil
# 6   Restaurant              -3.747300 -38.499797  2029      BR  Brasil
# 24  Brazilian Restaurant    -3.747915 -38.481119  2037      BR  Brasil
# 23  Restaurant              -3.750328 -38.504158  2051      BR  Brasil
# 27  Restaurant              -3.746459 -38.501324  2195      BR  Brasil
# 12  Chinese Restaurant      -3.782034 -38.498508  2243      BR  Brasil
# 11  Restaurant              -3.746474 -38.503719  2343      BR  Brasil
#
#                           id
# 2   563ccfeecd10bfc081e30a20
# 0   4e9d9eb72c5b8638e57d7daa
# 4   50358c52e4b0cf42407560f7
# 5   5183e155498e448ef51b3f99
# 3   52791a8b498e214e9f44f815
# 8   50e5a4ece4b06f58a73ba41f
# 15  53a42a06498ea4bed5a9ac26
# 21  509eea6ae4b01718b2ee95a1
# 14  4e94e6566d8689834d758cf8
# 20  4ffc446ee4b09736bd11d339
# 18  55439f30498ef2b968962fb9
# 26  543e7e63498e6f51e7216fc4
# 17  505c72b0e4b05434c060f07b
# 25  5a1f2f04c0f1634ab4e85b48
# 29  5555490b498ecb1f1108e821
# 13  55bf5a5b498e34359819b58e
# 10  4fa81bd1e4b0548308cd893d
# 1   4cfe445b2c1aa0907422067a
# 7   572cf0de498ea4b92e314c1c
# 16  4f846840e4b07ae14168a76d
# 9   4fa93f5ee4b007be2cc77ed2
# 28  506b0cfde4b0b2645d2250d8
# 22  4ed3aee18b81b4739a5777ea
# 19  545b9151498eac0b6597fe40
# 6   4de66c6fd1648041649f33b1
# 24  506b105de4b0670d3fe3e137
# 23  4eebea008b81bbbf5b6093d0
# 27  4f5f5bf6e4b040463da3637b
# 12  4ced2eded7268cfacaa5c14e
# 11  54ff0de2498e1fc1414700f7

# %% [markdown]
# #### Let's visualize the restaurants that are nearby

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(fortaleza_df.lat, fortaleza_df.lng, fortaleza_df.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Overal rating

# %%
#lets check the closest one
venue_id = '563ccfeecd10bfc081e30a20' # ID of Restaurante da fa7
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/563ccfeecd10bfc081e30a20?client_id=EZTP0DUNMD3TKQDJDOQFXN3ORJU4FCB5W4RG4DLMVDCGRGFT&client_secret=E12WSECYOLAAVMEKS0KSMWJYG4XUQMFZJQ305DCV4N1VLW1E&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '563ccfeecd10bfc081e30a20',
#  'name': 'Restaurante Da Fa7',
#  'contact': {},
#  'location': {'lat': -3.766255879406433,
#   'lng': -38.4943828993284,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': -3.766255879406433,
#     'lng': -38.4943828993284}],
#   'cc': 'BR',
#   'country': 'Brasil',
#   'formattedAddress': ['Brasil']},
#  'canonicalUrl': 'https://foursquare.com/v/restaurante-da-fa7/563ccfeecd10bfc081e30a20',
#  'categories': [{'id': '52e81612bcbc57f1066b7a00',
#    'name': 'Comfort Food Restaurant',
#    'pluralName': 'Comfort Food Restaurants',
#    'shortName': 'Comfort Food',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'likes': {'count': 0, 'groups': []},
#  'dislike': False,
#  'ok': False,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 0, 'groups': []},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1446825966,
#  'tips': {'count': 0,
#   'groups': [{'type': 'others', 'name': 'All tips', 'count': 0, 'items': []}]},
#  'shortUrl': 'http://4sq.com/1Q8xibW',
#  'timeZone': 'America/Fortaleza',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': []}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.') #id of the closest one - Restaurante da Fa7
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4e9d9eb72c5b8638e57d7daa' # ID of Dona Malu

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.4

# %%
venue_id = '50358c52e4b0cf42407560f7' # ID of ERestaurante Churrascaria Serrana
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 0

# %% [markdown]
# ## 4. Explore a location
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### So, you just finished your gourmet dish at Ecco, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Ecco Restaurant.

# %%
latitude = -3.759449
longitude = -38.487703

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=EZTP0DUNMD3TKQDJDOQFXN3ORJU4FCB5W4RG4DLMVDCGRGFT&client_secret=E12WSECYOLAAVMEKS0KSMWJYG4XUQMFZJQ305DCV4N1VLW1E&ll=-3.759449,-38.487703&v=20180604&radius=2000&limit=30'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Dona Malu restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Dona Malu restaurant.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4b94132bf964a520286634e3',
#   'name': 'Saraiva MegaStore',
#   'location': {'address': 'Shopping Center Iguatemi',
#    'crossStreet': 'Shopping Iguatemi - Loja 6',
#    'lat': -3.757714949097218,
#    'lng': -38.488261262561416,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': -3.757714949097218,
#      'lng': -38.488261262561416}],
#    'distance': 202,
#    'postalCode': '60811-340',
#    'cc': 'BR',
#    'city': 'Fortaleza',
#    'state': 'CE',
#    'country': 'Brasil',
#    'formattedAddress': ['Shopping Center Iguatemi (Shopping Iguatemi - Loja 6)',
#     'Fortaleza, CE',
#     '60811-340',
#     'Brasil']},
#   'categories': [{'id': '4bf58dd8d48988d114951735',
#     'name': 'Bookstore',
#     'pluralName': 'Bookstores',
#     'shortName': 'Bookstore',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4b94132bf964a520286634e3-0'}

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                name            categories  \
# 0  Saraiva MegaStore                 Bookstore
# 1  Greenlife Family Club Academia    Gym / Fitness Center
# 2  Empório Brownie                   Dessert Shop
# 3  La Frontera                       Mexican Restaurant
# 4  Yozenn                            Frozen Yogurt Shop
# 5  Calvin Klein Jeans                Boutique
# 6  Shopping Center Iguatemi          Shopping Mall
# 7  Santa Grelha Iguatemi             Bistro
# 8  Ibis Fortaleza Centro de Eventos  Hotel
# 9  Tio Armênio - Iguatemi            Restaurant
#
#                                          address                 crossStreet  \
# 0  Shopping Center Iguatemi                       Shopping Iguatemi - Loja 6
# 1  Avenida Coronel Miguel Dias, 200 - Guararapes  NaN
# 2  Shopping Iguatemi                              NaN
# 3  Rua Eliseu Uchoa Becca,  450                   NaN
# 4  Shopping Iguatemi                              NaN
# 5  Shopping Center Iguatemi                       Piso superior, Lj. 519
# 6  Av. Washington Soares, 85                      NaN
# 7  Shopping Iguatemi                              NaN
# 8  Rua Firmino Rocha De Aguiar, 1799              NaN
# 9  NaN                                            NaN
#
#         lat        lng  \
# 0 -3.757715 -38.488261
# 1 -3.759317 -38.488339
# 2 -3.757121 -38.488586
# 3 -3.761136 -38.486534
# 4 -3.757109 -38.488610
# 5 -3.757518 -38.488253
# 6 -3.756287 -38.488711
# 7 -3.756413 -38.489297
# 8 -3.763138 -38.485757
# 9 -3.756800 -38.488995
#
#                                                                    labeledLatLngs  \
# 0  [{'label': 'display', 'lat': -3.757714949097218, 'lng': -38.488261262561416}]
# 1  [{'label': 'display', 'lat': -3.7593166597769536, 'lng': -38.48833903215285}]
# 2  [{'label': 'display', 'lat': -3.7571210767965693, 'lng': -38.488585764712916}]
# 3  [{'label': 'display', 'lat': -3.761135608063281, 'lng': -38.48653443514369}]
# 4  [{'label': 'display', 'lat': -3.757109152021592, 'lng': -38.48861027681697}]
# 5  [{'label': 'display', 'lat': -3.7575179778495476, 'lng': -38.48825283025476}]
# 6  NaN
# 7  [{'label': 'display', 'lat': -3.7564127299080576, 'lng': -38.48929731794352}]
# 8  [{'label': 'display', 'lat': -3.7631384886042896, 'lng': -38.485756805010396}]
# 9  [{'label': 'display', 'lat': -3.756800489596541, 'lng': -38.48899542932136}]
#
#    distance postalCode  cc       city state country  \
# 0  202       60811-340  BR  Fortaleza  CE    Brasil
# 1  72        60810-160  BR  Fortaleza  CE    Brasil
# 2  277       NaN        BR  Fortaleza  CE    Brasil
# 3  228       NaN        BR  Fortaleza  CE    Brasil
# 4  279       60811-340  BR  Fortaleza  CE    Brasil
# 5  223       60811-340  BR  Fortaleza  CE    Brasil
# 6  369       60811-340  BR  Fortaleza  CE    Brasil
# 7  381       NaN        BR  Fortaleza  CE    Brasil
# 8  464       60810-165  BR  Fortaleza  CE    Brasil
# 9  327       NaN        BR  NaN        NaN   Brasil
#
#                                                                             formattedAddress  \
# 0  [Shopping Center Iguatemi (Shopping Iguatemi - Loja 6), Fortaleza, CE, 60811-340, Brasil]
# 1  [Avenida Coronel Miguel Dias, 200 - Guararapes, Fortaleza, CE, 60810-160, Brasil]
# 2  [Shopping Iguatemi, Fortaleza, CE, Brasil]
# 3  [Rua Eliseu Uchoa Becca,  450, Fortaleza, CE, Brasil]
# 4  [Shopping Iguatemi, Fortaleza, CE, 60811-340, Brasil]
# 5  [Shopping Center Iguatemi (Piso superior, Lj. 519), Fortaleza, CE, 60811-340, Brasil]
# 6  [Av. Washington Soares, 85, Fortaleza, CE, 60811-340, Brasil]
# 7  [Shopping Iguatemi, Fortaleza, CE, Brasil]
# 8  [Rua Firmino Rocha De Aguiar, 1799, Fortaleza, CE, 60810-165, Brasil]
# 9  [Brasil]
#
#   neighborhood                        id
# 0  NaN          4b94132bf964a520286634e3
# 1  NaN          57fba918498ed8ace1612628
# 2  NaN          4e95d0a76c25df8da7c98373
# 3  NaN          5647c2ac498e83af8e280751
# 4  NaN          5249cd1611d28686cf52416f
# 5  NaN          4ccb95e664a6199c6f3a14c1
# 6  NaN          4b632514f964a5202d662ae3
# 7  NaN          555a126a498e352448be25b0
# 8  NaN          5683d714498ea2caa9d7581d
# 9  NaN          55c938cd498efb5581ee44c9

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add dona malu as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Dona Malu',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item5"></a>

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ed92969216785001b22c122'},
#  'response': {'venues': []}}

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# Now, depending on when you run the above code, you might get different venues since the venues with the highest foot traffic are fetched live.

# %% [markdown]
# ### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item6"></a>
